# %%
import numpy as np

# %%
vocab_size = 100
seqence_length = 6
embedding_dim = 4

# %%
tokens = np.random.randint(0, vocab_size, seqence_length).T
tokens
# Out:
# array([67, 87,  0, 89, 25, 49])

# %%
token_embedding_weights = np.random.random((vocab_size, embedding_dim))
token_embedding_weights
# Out:
# array([[0.89964363, 0.0551854 , 0.8999625 , 0.94375423],
#        [0.78065258, 0.6277509 , 0.40663695, 0.835714  ],
#        [0.70465611, 0.11960769, 0.5570336 , 0.45693388],
#        [0.10730183, 0.69842841, 0.09305236, 0.19085717],
#        [0.97140054, 0.0289729 , 0.32223996, 0.96758507],
#        [0.17653189, 0.88044843, 0.05986584, 0.7943084 ],
#        [0.49278308, 0.85288123, 0.89766422, 0.95436226],
#        [0.85593217, 0.4202536 , 0.56495814, 0.0326887 ],
#        [0.43959502, 0.02537245, 0.87314256, 0.28289205],
#        [0.97843662, 0.57915249, 0.91616609, 0.83823164],
#        [0.57058344, 0.88176936, 0.30944651, 0.71581483],
#        [0.5510557 , 0.02222561, 0.08489878, 0.08544463],
#        [0.29790817, 0.76630135, 0.5195242 , 0.22447278],
#        [0.46024697, 0.46266707, 0.44916816, 0.76832442],
#        [0.42367004, 0.15809843, 0.55543316, 0.98539044],
#        [0.82933667, 0.41385263, 0.39925797, 0.83407786],
# ...

# %%
import tiktoken

# %%
tokenizer = tiktoken.get_encoding('gpt2')

# %%
tokenizer.n_vocab
# Out:
# 50257

# %% [markdown]
# $X^{'} = \frac{X - X_{min}}{X_{max}-X_{min}}$
